# %% [markdown]
# Hola! Bienvenido al curso de adquisición de datos

# %% [markdown]
# sesion-1: Presentación

# %% [markdown]
# Las fuentes, desde registros en línea y transacciones comerciales, hasta interacciones en redes sociales y comportamiento del usuario, son parte de la adquisición de datos; para esto, se emplean diversas técnicas y tecnologías, asegurando así la precisión y la calidad de los datos recopilados.
#
# En otras palabras, el uso de la adquisición de datos hace posible que las empresas tomen decisiones informadas y estratégicas, haciendo posible abrir nuevas perspectivas y oportunidades para la innovación y el crecimiento.
#
# Por eso es importante que cualquier individuo dueño de un negocio conozca la importancia de la adquisición de datos, pues dicha práctica es un pilar esencial para alcanzar el éxito y mantenerse a la vanguardia en un mundo altamente competitivo y en constante cambio.
#
# Si usted desea saber cómo funciona esta poderosa herramienta para transformar la forma en la que operan diversos ámbitos de su empresa, en este artículo se lo explicamos a detalle.
#
# **¿Qué es la adquisición de datos?**
# La adquisición de datos se trata de recopilar y de obtener toda la información relevante y significativa a partir de diversas fuentes o dispositivos, este tipo de práctica es excelente para las empresas porque permite darles datos útiles y precisos para su posterior análisis, pudiendo hacer uso de ellos en distintos contextos.
#
# Por ende, la toma de decisiones, el análisis de tendencias, la identificación de patrones, la investigación y la optimización de procesos, son parte del proceso de adquisición de datos, donde además se incluyen las bases de datos, registros en línea, sensores, dispositivos móviles, redes sociales, encuestas y otros canales de interacción.
#
# De este modo, se puede describir a la adquisición de datos como un desarrollo en donde se muestra toda la información física del mundo real, y cuyas muestras se traducen en valores digitales en las computadoras para después tomar decisiones informadas, generando así crecimiento y asegurando el éxito de la empresa.
#
# **¿Para qué sirve la adquisición de datos?**
# Dentro de las empresas, la adquisición de datos se usa para diferentes propósitos, no obstante, tiene otras utilidades en diversas áreas y sectores, tales como los de a continuación:
#
# **Toma de decisiones informadas:** La adquisición de datos proporciona información que funciona para tomar decisiones basadas en datos y objetivos reales, en lugar de suposiciones o intuiciones.
# **Análisis de tendencias y patrones:** Los datos son analizados para identificar tendencias y patrones emergentes en diferentes áreas.
# Optimización de procesos: La recopilación es una manera de identificar las ineficiencias y áreas que se tienen que mejorar, teniendo así un aumento en la eficiencia operativa.
# **Investigación y desarrollo:** Dentro de los ámbitos científicos y de investigación, la adquisición de datos se usa tanto para análisis, como para pruebas y descubrimientos en diversos campos.
# Personalización y experiencia del cliente: La recopilación de datos ofrece una experiencia personalizada, por lo que otorga productos y servicios específicos.
# Marketing y publicidad: Los datos adquiridos segmentan y dirigen audiencias específicas, lo que resulta ideal para generar publicidad más efectiva y orientada.
# **Seguimiento y monitoreo:** Monitorea el rendimiento de sistemas y dispositivos, de igual manera, realiza seguimiento de indicadores clave.
# Prevención de riesgos y seguridad: La recopilación y análisis de datos identifica los riesgos y vulnerabilidades en diferentes escenarios.
# Planificación estratégica: Los datos adquiridos otorgan una visión más clara de las oportunidades y desafíos en el horizonte.
# **¿Cómo funciona la adquisición de datos?**
# Como la adquisición de datos consiste en un proceso sistemático de recopilación cuyo objetivo es generar información relevante desde diversas fuentes, tiene una manera puntual de ejecutarse, tal y como se muestra a continuación:
#
# **Identificación de fuentes de datos:** En el primer paso, se identifican las fuentes de donde se obtendrán los datos, así que las fuentes pueden venir de una base de datos, registros en línea, sensores, dispositivos móviles, redes sociales, encuestas, entre otros.
#
#
# **Importancia de los sistemas de adquisición de datos**
# Los sistemas de adquisición de datos son de vital importancia en diversos campos y sectores por las siguientes razones:
#
# Toma de decisiones informada
# Optimización de procesos
# Análisis y mejora de rendimiento
# Monitoreo de condiciones
# Investigación y desarrollo
# Personalización y experiencia del cliente
# Seguridad y prevención de riesgos
# Innovación y competitividad
# Principales tipos de insumos que mide un sistema de adquisición de datos
# Los sistemas de adquisición de datos poseen la capacidad de medir una amplia variedad de insumos, como los siguientes:
#
# Magnitudes físicas
# Señales eléctricas
# Medición de datos relacionados con el ambiente
# Medición de datos de procesos de producción
# Datos de comportamiento en línea
# Datos de salud y biomédicos
# Datos de tráfico y transporte
# Datos geoespaciales
# ¿Cuáles son los mejores equipos para la adquisición de datos?
# Los siguientes ejemplos son equipos útiles para la adquisición de datos, ya que destacan por ser herramientas tanto versátiles como fundamentales en diversas industrias y áreas de investigación.

# %% [markdown]
# --------------------------------------------------------------------------------

# %% [markdown]
# 1.   **Primer paso leeremos que es Octave:**
#         Octave o GNU Octave es un programa y lenguaje de programación para realizar cálculos numéricos. Como su nombre indica, Octave es parte del proyecto GNU. Es considerado el equivalente libre de MATLAB. Entre varias características que comparten, se puede destacar que ambos ofrecen un intérprete, permitiendo ejecutar órdenes en modo interactivo. Nótese que Octave no es un sistema de álgebra computacional, como lo es Maxima, sino que está orientado al análisis numérico.
#
# 2.   **Instalaremos Octave en nuestro sistema remoto Linux**, siguiendo este comado:
#         Dar click en en simbolo de Play lado izquierdo.
#
# 3.   **Recuerda estudiar los comandos de la terminal de Linux, son muy imoprtantes.**

# %% [markdown]
# *   **Éste paso se ejecutará cada vez que iniciemos nuestra maquina remota**

# %%
! sudo apt update
! sudo apt install octave
! sudo apt install -y liboctave-dev
# Out:
# Get:1 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:2 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:3 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Hit:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:7 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Get:8 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [1,900 kB]
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:10 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,090 kB]
# Get:11 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [2,453 kB]
# Hit:12 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# ...

# %% [markdown]
# --------------------------------------------------------------------------------

# %% [markdown]
# sesion-2: Divisor de Tensión lineal

# %%
# %%writefile divT_GGT.m
# % clear all; % Borra todas las variables
# % clear; % Borra ventana de comandos
# clc; % Borra ventana de comandos
# % Close all; % Borra todas las ventanas
#
# % Entrada de valores de resistencia fija R1 y voltaje de alimentación (VIN)%
# R1 = 1000;
# R2 = 10000;
# R3 = 100000;
# VIN = 5;
#
# RVAR = (1:100:100000); % Cálculo del voltaje de salida del divisor de tensión con una resistencia variable de 100K en serie con la resistencia R1
# VO1 = VIN * (RVAR ./ (R1 + RVAR));
#
# RVAR = (1:100:100000); % Cálculo del voltaje de salida del divisor de tensión con una resistencia variable de 100K en serie con la resistencia R2
# VO2 = VIN * (RVAR ./ (R2 + RVAR));
#
# RVAR = (1:100:100000); % Cálculo del voltaje de salida del divisor de tensión con una resistencia variable de 100K en serie con la resistencia R3
# VO3 = VIN * (RVAR ./ (R3 + RVAR));
#
# % Combine all data into one matrix
# data_matrix = [RVAR', VO1', VO2', VO3'];
#
# % Write the combined data to a single CSV file
# csvwrite('combined_data.csv', data_matrix);
#
# % Plot the data
# plot(RVAR, VO1, "k:", RVAR, VO2, "r*", RVAR, VO3, "b--");
# title("Gráfica GTG");
# legend("VO1", "VO2", "VO3");
# xlabel("Resistencia variable");
# ylabel("Voltaje de salida");
# print -dpng divT_GGT.png

# %%
! octave divT_GGT.m

# %% [markdown]
# --------------------------------------------------------------------------------

# %% [markdown]
# sesion-3: Divisor de Tensión logarítmico

# %%
# %%writefile divTLog_GGT.m
# % Define parameters
# R1 = 1000; % Resistance in ohms - please modify this value
# R2 = 1000; % Resistance in ohms - please modify this value
# Vin = 10000;  % Input voltage in volts - please modify this value
#
# % Define a range of input voltages
# Vin_range = linspace(0, Vin, 1000);
#
# % Calculate output voltage for each input voltage
# Vout = R2 ./ (R1 + R2) .* log(1 + Vin_range / R1);
#
# % Plot the results
# plot(Vin_range, Vout, 'b', 'LineWidth', 2);
# xlabel('Input Voltage (V)');
# ylabel('Output Voltage (V)');
# title('Logarithmic Tension Divider');
# grid on;
# print -dpng divTLog_GGT.png
# Out:
# Overwriting divTLog_GGT.m

# %%
! octave divTLog_GGT.m
# Out:
# octave: X11 DISPLAY environment variable not set
# octave: disabling GUI features
# ...
#
# The gnuplot graphics toolkit is not actively maintained and has a number
# of limitations that are ulikely to be fixed.  Communication with gnuplot
# uses a one-directional pipe and limited information is passed back to the
# Octave interpreter so most changes made interactively in the plot window
# will not be reflected in the graphics properties managed by Octave.  For
# example, if the plot window is closed with a mouse click, Octave will not
# be notified and will not update it's internal list of open figure windows.
# We recommend using the qt toolkit instead.
#
#
#          |------------------Logarithmic Tension Divider---------------------|
#     1.4 +|+##########+#############+############+#############+##########+-+|
#         +|           +             +            +             +            +|
#     1.2 #|+##############################################################+**|
# ...

# %% [markdown]
# --------------------------------------------------------------------------------

# %% [markdown]
# sesion-4: Análsis de errores en instrumentación

# %%
# %%writefile errores.m
# clear;
# clc;
#
# % Input data
# datain = [0.000; 1.000; 2.000; 3.000; 4.000; 5.000; 6.000; 7.000; 8.000; 9.000; 10.000];
# dataoutup = [-1.12; 0.21; 1.18; 2.09; 3.33; 4.50; 5.26; 6.59; 7.73; 8.68; 9.80];
# dataoutdown = [-0.69; 0.42; 1.65; 2.48; 3.62; 4.71; 5.87; 6.89; 7.92; 9.10; 10.20];
#
# % Calculate the average of the ascending and descending data
# dataprom = (dataoutdown + dataoutup) / 2;
#
# % Fit the data using least squares
# qup = polyfit(datain, dataoutup, 1);
# qdown = polyfit(datain, dataoutdown, 1);
# qprom = polyfit(datain, dataprom, 1);
#
# % Number of samples
# N = length(datain);
#
# % Calculate delta
# M1 = N * sum(datain.^2);  % Changed ^ to .^
# M2 = sum(datain)^2;
# M12 = M1 - M2;
#
# % Calculate m and b
# m1 = N * sum(datain .* dataprom);
# m2 = sum(datain) * sum(dataprom);
# mf = (m1 - m2) / M12;
#
# bb1 = sum(dataprom);
# bb2 = sum(datain.^2);  % Changed ^ to .^
# b1 = bb1 * bb2;
# b2 = sum(datain .* dataprom) * sum(datain);
# bf = (b1 - b2) / M12;
#
# % Generate the fitted line
# mreal = qprom(1);
# breal = qprom(2);
# y1 = mreal * datain + breal;
#
# % Plot the data and the fitted line
# figure(1);
# plot(datain, dataprom, 'r*');
# xlabel('Datos de Entrada');
# ylabel('Datos de Salida sin ajuste');
# hold on;
# plot(datain, dataprom);
# hold off;
#
# figure(2);
# plot(datain, y1, 'r+', datain, datain, 'b*');
# xlabel('Datos de Entrada');
# ylabel('Datos de Salida con ajuste');
# hold on;
# plot(datain, y1);
# hold off;
#
# % Calculate real data from the fit
# datainreal = y1 * 1.082 - 0.846;
#
# % Calculate uncertainties
# p1 = mf * datain;
# A = p1';
#
# bfreal = repmat(bf, N, 1);
# B = dataprom - bfreal;
# C = (B - A).^2;  % Changed ^ to .^
# p4 = sum(C);
# Sqo2 = (1 / (N - 2)) * p4;
# Sqo = sqrt(Sqo2);
#
# % Uncertainty of the slope
# Sm = Sqo * sqrt(N / M12);
#
# % Uncertainty of the intercept
# Sb = Sqo * sqrt(sum(datain.^2) / M12);  % Changed ^ to .^
#
# % Three standard deviations
# SbF = 3 * Sb;
# SmF = 3 * Sm;
#
# fprintf('y = (x) * %2.3f + %5.3f \n\n', mreal, breal);
# fprintf('pendiente = %2.3f\n', mf);
# fprintf('cruce con la ordenada (offset) = %2.3f\n', bf);
# fprintf('desviacion estandar de la pendiente = %2.3f\n', Sm);
# fprintf('desviacion estandar del cruce por la ordenada = %2.3f\n', Sb);
# fprintf('Tres desviaciones estandar de la pendiente = %2.3f\n', SmF);
# fprintf('Tres desviaciones estandar del cruce por la ordenada = %2.3f\n', SbF);
#
# % Determination of Sqi
# mfreal = repmat(mf, N, 1);
# qi = (y1 + bfreal) ./ mfreal;
# Sqi = sqrt(Sqo.^2 / mf.^2);
#
# % Instrumental errors
# eabs = abs(max(datain) - max(y1));
# erel = eabs / max(datain);
# erelp = erel * 100;
# exa = abs((1 - erel) * 100);
# fprintf('error absoluto = %2.3f\n', eabs);
# fprintf('error relativo porcentual = %2.3f\n', erelp);
# fprintf('exactitud = %2.3f\n', exa);
#
# % Hysteresis
# dif = abs(dataoutup - dataoutdown);
# eh = max(dif);
# eH = (eh / max(datain)) * 100;
# fprintf('\n eH = %2.3f por ciento %5.3f \n\n', eH);
#
# % Linearity
# difL = abs(datain - y1);
# el = max(difL);
# eL = (el / max(datain)) * 100;
# fprintf('\n eL = %2.3f por ciento %5.3f \n\n', eL);
#
# % Sensitivity
# difk = abs(y1 - datain);
# ek = max(difk);
# eK = (ek / max(datain)) * 100;
# fprintf('\n eK = %2.3f por ciento %5.3f \n', eK);
#
# % Zero shift
# difz = abs(y1(1) - datain(1));
# ez = max(difz);
# eZ = (ez / max(datain)) * 100;
# fprintf('\n eZ = %2.3f por ciento %5.3f \n', eZ);
#
# % Repeatability
# eR = (2 * Sqi / max(datain)) * 100;
# fprintf('\n eR = %2.3f por ciento %5.3f \n', eR);
#
# % Instrument uncertainty
# UI = max(datain) * sqrt((eH / 100).^2 + (eL / 100).^2 + (eK / 100).^2 + (eZ / 100).^2 + (eR / 100).^2);
#
# % Design uncertainty
# Uo = 0.5 * (datain(2) - datain(1));
# UD = sqrt(Uo.^2 + UI.^2) * 10;
# fprintf('\n Incertidumbre de diseño UD = %2.3f\n', UD);
# print -dpng errores.png
# Out:
# Overwriting errores.m

# %%
! octave errores.m

# %% [markdown]
# sesion-5: Análsis de datos Temperatura vs Tiempo

# %%
# %%writefile temperature_vs_time.m
#
# % Generate synthetic data
# n = 1000; % Number of data points (reduced for demonstration)
# time = linspace(1, 100, n); % Time data
# temperature = 0.5 * time + 10 + randn(1, n) * 2; % Linear relationship with noise
#
# % Perform least squares fitting
# X = [ones(size(time)); time];
# coefficients = (X * X') \ (X * temperature');
#
# % Calculate fitted values
# fitted_values = X' * coefficients;
#
# % Plot the data and the fitted line
# plot(time, temperature, '.', 'MarkerSize', 10); hold on;
# plot(time, fitted_values, 'r', 'LineWidth', 2);
# xlabel('Time');
# ylabel('Temperature');
# title('Least Squares Fitting of Temperature vs Time');
# legend('Data', 'Fitted Line');
# grid on;
# print -dpng temperature_vs_time.png
# Out:
# Writing temperature_vs_time.m

# %%
! octave temperature_vs_time.m

# %% [markdown]
# sesion-6: Análsis de datos IMECAS Jalisco 2022

# %% [markdown]
# Necesitas subir el archivo datos_2022.xlsx y copiar su ruta dando click derecho copiar ruta, pegar en el codigo en la parte donde acarga el archivo.

# %%
! pip install pandas scikit-learn openpyxl matplotlib statsmodels

# %%
# %%writefile linear_regression_imecas.py
import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA

# Load the Excel file
file_path = '/content/datos_2022.xlsx'  # Replace with your path file name
sheet_name = 'SIMAJ2022'

# Read the Excel file
df = pd.read_excel(file_path, sheet_name=sheet_name)

# Extract the required columns
data = df[['Estacion', 'Date_Time', 'TMPI']]

# Filter rows where 'Estacion' is 'Oblatos'
data = data[data['Estacion'] == 'Vallarta'] # Aqui puedes cambiar de Estacion

# Convert 'Date_Time' to datetime format
data['Date_Time'] = pd.to_datetime(data['Date_Time'])

# Remove rows where 'TMPI' contains the strings 'IR', 'IF', or 'ND'
data = data[~data['TMPI'].isin(['IR', 'IF', 'ND'])]

# Convert 'TMPI' to numeric, errors='coerce' will convert non-numeric values to NaN
data['TMPI'] = pd.to_numeric(data['TMPI'], errors='coerce')

# Drop rows with NaN values
data = data.dropna(subset=['TMPI'])

# Prepare the data for linear regression
# Convert 'Date_Time' to numerical format (e.g., timestamp)
data['Date_Time_Num'] = data['Date_Time'].astype(int) / 10**9  # Convert to seconds

X = data[['Date_Time_Num']]
y = data['TMPI']

# Create and fit the linear regression model
model = LinearRegression()
model.fit(X, y)

# Print the regression coefficients
print("Intercept:", model.intercept_)
print("Coefficient:", model.coef_[0])

# Predict using the model
data['TMPI_Predicted'] = model.predict(X)

# Plot the linear regression results
plt.figure(figsize=(10, 6))
plt.scatter(data['Date_Time'], data['TMPI'], color='blue', label='Actual TMPI')
plt.plot(data['Date_Time'], data['TMPI_Predicted'], color='red', linewidth=2, label='Predicted TMPI')
plt.xlabel('Date Time')
plt.ylabel('TMPI')
plt.title('Linear Regression of TMPI over Time (Oblatos)')
plt.legend()
plt.grid(True)

# Save the linear regression plot as a PNG file
output_file_lr = 'TMPI_linear_regression_oblatos.png'
plt.savefig(output_file_lr)

# Optional: Close the plot to free up memory
plt.close()

print(f"Linear regression plot saved as {output_file_lr}")

# Perform ARIMA analysis
# Use 'Date_Time' as index for time series analysis
data.set_index('Date_Time', inplace=True)

# Fit ARIMA model (order can be tuned)
arima_model = ARIMA(data['TMPI'], order=(5, 1, 0))
arima_result = arima_model.fit()

# Predict using the ARIMA model
data['TMPI_ARIMA_Predicted'] = arima_result.predict(start=0, end=len(data)-1, dynamic=False)

# Plot the ARIMA results
plt.figure(figsize=(10, 6))
plt.plot(data.index, data['TMPI'], color='blue', label='Actual TMPI')
plt.plot(data.index, data['TMPI_ARIMA_Predicted'], color='green', linewidth=2, label='ARIMA Predicted TMPI')
plt.xlabel('Date Time')
plt.ylabel('TMPI')
plt.title('ARIMA Analysis of TMPI over Time (Oblatos)')
plt.legend()
plt.grid(True)

# Save the ARIMA plot as a PNG file
output_file_arima = 'TMPI_arima_analysis_oblatos.png'
plt.savefig(output_file_arima)

# Optional: Close the plot to free up memory
plt.close()

print(f"ARIMA analysis plot saved as {output_file_arima}")
# Out:
# Overwriting linear_regression_imecas.py

# %% [markdown]
# Ésta acción tomará algunos minutos

# %%
! python linear_regression_imecas.py
# Out:
# Intercept: 45.21494071727853
# Coefficient: -1.3697164753029354e-08
# Linear regression plot saved as TMPI_linear_regression_oblatos.png
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# ARIMA analysis plot saved as TMPI_arima_analysis_oblatos.png
